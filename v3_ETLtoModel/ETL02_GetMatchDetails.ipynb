# %%
# get match details and add these to postgres
import requests
import pandas as pd
import numpy as np
import psycopg2
import json
import time
import support_EventLogger as logger

# %%
process_name = 'ETL02_GetMatchDetails.ipynb' # for logger
#logger.log(process_name,'Process started, libraries loaded')

# %%
target_match = 7215991100

# %%
api_string = "https://api.opendota.com/api/matches/"+str(target_match)
#response = requests.get(api_string)
if response.status_code == 200:
    print("YAY!")
else:
    print("...")
# Out:
# YAY!

# %%
match = response.json()
match
# Out:
# {'match_id': 7215991100,
#  'barracks_status_dire': 63,
#  'barracks_status_radiant': 63,
#  'chat': None,
#  'cluster': 122,
#  'cosmetics': None,
#  'dire_score': 9,
#  'dire_team_id': None,
#  'draft_timings': None,
#  'duration': 582,
#  'engine': 1,
#  'first_blood_time': 48,
#  'game_mode': 22,
#  'human_players': 10,
#  'leagueid': 0,
#  'lobby_type': 0,
#  'match_seq_num': 6066913687,
#  'negative_votes': 0,
#  'objectives': None,
#  'picks_bans': [{'is_pick': True, 'hero_id': 43, 'team': 1, 'order': 0},
#   {'is_pick': True, 'hero_id': 28, 'team': 1, 'order': 1},
#   {'is_pick': True, 'hero_id': 68, 'team': 0, 'order': 2},
#   {'is_pick': True, 'hero_id': 17, 'team': 1, 'order': 3},
#   {'is_pick': True, 'hero_id': 21, 'team': 0, 'order': 4},
#   {'is_pick': True, 'hero_id': 27, 'team': 1, 'order': 5},
#   {'is_pick': True, 'hero_id': 4, 'team': 0, 'order': 6},
#   {'is_pick': True, 'hero_id': 59, 'team': 1, 'order': 7},
#   {'is_pick': False, 'hero_id': 4, 'team': 0, 'order': 8},
#   {'is_pick': False, 'hero_id': 75, 'team': 0, 'order': 9},
#   {'is_pick': False, 'hero_id': 93, 'team': 0, 'order': 10},
#   {'is_pick': False, 'hero_id': 1, 'team': 0, 'order': 11},
#   {'is_pick': False, 'hero_id': 70, 'team': 0, 'order': 12}],
#  'positive_votes': 0,
#  'radiant_gold_adv': None,
#  'radiant_score': 1,
#  'radiant_team_id': None,
#  'radiant_win': False,
#  'radiant_xp_adv': None,
#  'skill': None,
#  'start_time': 1687725487,
#  'teamfights': None,
#  'tower_status_dire': 2047,
#  'tower_status_radiant': 1982,
#  'version': None,
#  'replay_salt': 1125375967,
#  'series_id': 0,
#  'series_type': 0,
#  'players': [{'match_id': 7215991100,
#    'player_slot': 0,
#    'ability_targets': None,
#    'ability_upgrades_arr': [5016, 5017, 5017, 5015],
#    'ability_uses': None,
#    'account_id': None,
#    'actions': None,
#    'additional_units': None,
#    'assists': 1,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'backpack_3': None,
#    'buyback_log': None,
#    'camps_stacked': None,
#    'connection_log': None,
#    'creeps_stacked': None,
#    'damage': None,
#    'damage_inflictor': None,
#    'damage_inflictor_received': None,
#    'damage_taken': None,
#    'damage_targets': None,
#    'deaths': 1,
#    'denies': 14,
#    'dn_t': None,
#    'firstblood_claimed': None,
#    'gold': 0,
#    'gold_per_min': 235,
#    'gold_reasons': None,
#    'gold_spent': 2295,
#    'gold_t': None,
#    'hero_damage': 1432,
#    'hero_healing': 0,
#    'hero_hits': None,
#    'hero_id': 4,
#    'item_0': 50,
#    'item_1': 16,
#    'item_2': 0,
#    'item_3': 75,
#    'item_4': 16,
#    'item_5': 11,
#    'item_neutral': 0,
#    'item_uses': None,
#    'kill_streaks': None,
#    'killed': None,
#    'killed_by': None,
#    'kills': 0,
#    'kills_log': None,
#    'lane_pos': None,
#    'last_hits': 27,
#    'leaver_status': 1,
#    'level': 4,
#    'lh_t': None,
#    'life_state': None,
#    'max_hero_hit': None,
#    'multi_kills': None,
#    'net_worth': 2305,
#    'obs': None,
#    'obs_left_log': None,
#    'obs_log': None,
#    'obs_placed': None,
#    'party_id': 0,
#    'party_size': 1,
#    'performance_others': None,
#    'permanent_buffs': [],
#    'pings': None,
#    'pred_vict': None,
#    'purchase': None,
#    'purchase_log': None,
#    'randomed': None,
#    'repicked': None,
#    'roshans_killed': None,
#    'rune_pickups': None,
#    'runes': None,
#    'runes_log': None,
#    'sen': None,
#    'sen_left_log': None,
#    'sen_log': None,
#    'sen_placed': None,
#    'stuns': None,
#    'teamfight_participation': None,
#    'times': None,
#    'tower_damage': 0,
#    'towers_killed': None,
#    'xp_per_min': 159,
#    'xp_reasons': None,
#    'xp_t': None,
#    'radiant_win': False,
#    'start_time': 1687725487,
#    'duration': 582,
#    'cluster': 122,
#    'lobby_type': 0,
#    'game_mode': 22,
#    'is_contributor': False,
#    'patch': 52,
#    'region': 2,
#    'isRadiant': True,
#    'win': 0,
#    'lose': 1,
#    'total_gold': 2279,
#    'total_xp': 1542,
#    'kda': 0,
#    'abandons': 0,
#    'rank_tier': None,
#    'is_subscriber': False,
#    'cosmetics': [],
#    'benchmarks': {'gold_per_min': {'raw': 235, 'pct': 0},
#     'xp_per_min': {'raw': 159, 'pct': 0},
#     'kills_per_min': {'raw': 0, 'pct': 0.03636363636363636},
#     'last_hits_per_min': {'raw': 2.783505154639175, 'pct': 0},
#     'hero_damage_per_min': {'raw': 147.62886597938146,
#      'pct': 0.01818181818181818},
#     'hero_healing_per_min': {'raw': 0, 'pct': 0.9454545454545454},
#     'tower_damage': {'raw': 0, 'pct': 0.14545454545454545},
#     'stuns_per_min': {'raw': 0, 'pct': 0.6181818181818182},
#     'lhten': {}}},
#   {'match_id': 7215991100,
#    'player_slot': 1,
#    'ability_targets': None,
#    'ability_upgrades_arr': [5347, 5345, 5346, 5346],
#    'ability_uses': None,
#    'account_id': 125837,
#    'actions': None,
#    'additional_units': None,
#    'assists': 0,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'backpack_3': None,
#    'buyback_log': None,
#    'camps_stacked': None,
#    'connection_log': None,
#    'creeps_stacked': None,
#    'damage': None,
#    'damage_inflictor': None,
#    'damage_inflictor_received': None,
#    'damage_taken': None,
#    'damage_targets': None,
#    'deaths': 1,
#    'denies': 0,
#    'dn_t': None,
#    'firstblood_claimed': None,
#    'gold': 3179,
#    'gold_per_min': 403,
#    'gold_reasons': None,
#    'gold_spent': 1295,
#    'gold_t': None,
#    'hero_damage': 3837,
#    'hero_healing': 0,
#    'hero_hits': None,
#    'hero_id': 68,
#    'item_0': 29,
#    'item_1': 218,
#    'item_2': 0,
#    'item_3': 36,
#    'item_4': 216,
#    'item_5': 44,
#    'item_neutral': 0,
#    'item_uses': None,
#    'kill_streaks': None,
#    'killed': None,
#    'killed_by': None,
#    'kills': 1,
#    'kills_log': None,
#    'lane_pos': None,
#    'last_hits': 0,
#    'leaver_status': 1,
#    'level': 4,
#    'lh_t': None,
#    'life_state': None,
#    'max_hero_hit': None,
#    'multi_kills': None,
#    'net_worth': 4434,
#    'obs': None,
#    'obs_left_log': None,
#    'obs_log': None,
#    'obs_placed': None,
#    'party_id': 1,
#    'party_size': 1,
#    'performance_others': None,
#    'permanent_buffs': [],
#    'pings': None,
#    'pred_vict': None,
#    'purchase': None,
#    'purchase_log': None,
#    'randomed': None,
#    'repicked': None,
#    'roshans_killed': None,
#    'rune_pickups': None,
#    'runes': None,
#    'runes_log': None,
#    'sen': None,
#    'sen_left_log': None,
#    'sen_log': None,
#    'sen_placed': None,
#    'stuns': None,
#    'teamfight_participation': None,
#    'times': None,
#    'tower_damage': 0,
#    'towers_killed': None,
#    'xp_per_min': 168,
#    'xp_reasons': None,
#    'xp_t': None,
#    'personaname': 'GWツNNE',
#    'name': None,
#    'last_login': '2023-07-05T05:33:29.234Z',
#    'radiant_win': False,
#    'start_time': 1687725487,
#    'duration': 582,
#    'cluster': 122,
#    'lobby_type': 0,
#    'game_mode': 22,
#    'is_contributor': False,
#    'patch': 52,
#    'region': 2,
#    'isRadiant': True,
#    'win': 0,
#    'lose': 1,
#    'total_gold': 3909,
#    'total_xp': 1629,
#    'kills_per_min': 0.10309278350515465,
#    'kda': 0,
#    'abandons': 0,
#    'rank_tier': 42,
#    'is_subscriber': False,
#    'cosmetics': [],
#    'benchmarks': {'gold_per_min': {'raw': 403, 'pct': 0.8636363636363636},
#     'xp_per_min': {'raw': 168, 'pct': 0},
#     'kills_per_min': {'raw': 0.10309278350515463, 'pct': 0.6363636363636364},
#     'last_hits_per_min': {'raw': 0, 'pct': 0},
#     'hero_damage_per_min': {'raw': 395.5670103092783,
#      'pct': 0.5454545454545454},
#     'hero_healing_per_min': {'raw': 0, 'pct': 0.5909090909090909},
#     'tower_damage': {'raw': 0, 'pct': 0.3181818181818182},
#     'stuns_per_min': {'raw': 0, 'pct': 0},
#     'lhten': {}}},
#   {'match_id': 7215991100,
#    'player_slot': 2,
#    'ability_targets': None,
#    'ability_upgrades_arr': [5330, 5328, 5330],
#    'ability_uses': None,
#    'account_id': None,
#    'actions': None,
#    'additional_units': None,
#    'assists': 1,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'backpack_3': None,
#    'buyback_log': None,
#    'camps_stacked': None,
#    'connection_log': None,
#    'creeps_stacked': None,
#    'damage': None,
#    'damage_inflictor': None,
#    'damage_inflictor_received': None,
#    'damage_taken': None,
#    'damage_targets': None,
#    'deaths': 1,
#    'denies': 0,
#    'dn_t': None,
#    'firstblood_claimed': None,
#    'gold': 0,
#    'gold_per_min': 290,
#    'gold_reasons': None,
#    'gold_spent': 1990,
#    'gold_t': None,
#    'hero_damage': 969,
#    'hero_healing': 0,
#    'hero_hits': None,
#    'hero_id': 66,
#    'item_0': 29,
#    'item_1': 4,
#    'item_2': 94,
#    'item_3': 237,
#    'item_4': 216,
#    'item_5': 88,
#    'item_neutral': 375,
#    'item_uses': None,
#    'kill_streaks': None,
#    'killed': None,
#    'killed_by': None,
#    'kills': 0,
#    'kills_log': None,
#    'lane_pos': None,
#    'last_hits': 22,
#    'leaver_status': 1,
#    'level': 4,
#    'lh_t': None,
#    'life_state': None,
#    'max_hero_hit': None,
#    'multi_kills': None,
#    'net_worth': 2130,
#    'obs': None,
#    'obs_left_log': None,
#    'obs_log': None,
#    'obs_placed': None,
#    'party_id': 2,
#    'party_size': 1,
#    'performance_others': None,
#    'permanent_buffs': [],
#    'pings': None,
#    'pred_vict': None,
#    'purchase': None,
#    'purchase_log': None,
#    'randomed': None,
#    'repicked': None,
#    'roshans_killed': None,
#    'rune_pickups': None,
#    'runes': None,
#    'runes_log': None,
#    'sen': None,
#    'sen_left_log': None,
#    'sen_log': None,
#    'sen_placed': None,
#    'stuns': None,
#    'teamfight_participation': None,
#    'times': None,
#    'tower_damage': 0,
#    'towers_killed': None,
#    'xp_per_min': 145,
#    'xp_reasons': None,
#    'xp_t': None,
#    'radiant_win': False,
#    'start_time': 1687725487,
#    'duration': 582,
#    'cluster': 122,
#    'lobby_type': 0,
#    'game_mode': 22,
#    'is_contributor': False,
#    'patch': 52,
#    'region': 2,
#    'isRadiant': True,
#    'win': 0,
#    'lose': 1,
#    'total_gold': 2813,
#    'total_xp': 1406,
#    'kda': 0,
#    'abandons': 0,
#    'rank_tier': None,
#    'is_subscriber': False,
#    'cosmetics': [],
#    'benchmarks': {'gold_per_min': {'raw': 290, 'pct': 0.25},
#     'xp_per_min': {'raw': 145, 'pct': 0},
#     'kills_per_min': {'raw': 0, 'pct': 0.25},
#     'last_hits_per_min': {'raw': 2.268041237113402, 'pct': 0.25},
#     'hero_damage_per_min': {'raw': 99.89690721649485, 'pct': 0},
#     'hero_healing_per_min': {'raw': 0, 'pct': 0},
#     'tower_damage': {'raw': 0, 'pct': 0.25},
#     'stuns_per_min': {'raw': 0, 'pct': 0},
#     'lhten': {}}},
#   {'match_id': 7215991100,
#    'player_slot': 3,
#    'ability_targets': None,
#    'ability_upgrades_arr': [5132, 5130, 5131, 5131, 5131, 5133, 5131],
#    'ability_uses': None,
#    'account_id': 123332674,
#    'actions': None,
#    'additional_units': None,
#    'assists': 0,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'backpack_3': None,
#    'buyback_log': None,
#    'camps_stacked': None,
#    'connection_log': None,
#    'creeps_stacked': None,
#    'damage': None,
#    'damage_inflictor': None,
#    'damage_inflictor_received': None,
#    'damage_taken': None,
#    'damage_targets': None,
#    'deaths': 1,
#    'denies': 1,
#    'dn_t': None,
#    'firstblood_claimed': None,
#    'gold': 0,
#    'gold_per_min': 291,
#    'gold_reasons': None,
#    'gold_spent': 1915,
#    'gold_t': None,
#    'hero_damage': 2294,
#    'hero_healing': 0,
#    'hero_hits': None,
#    'hero_id': 21,
#    'item_0': 7,
#    'item_1': 0,
#    'item_2': 29,
#    'item_3': 0,
#    'item_4': 237,
#    'item_5': 0,
#    'item_neutral': 0,
#    'item_uses': None,
#    'kill_streaks': None,
#    'killed': None,
#    'killed_by': None,
#    'kills': 0,
#    'kills_log': None,
#    'lane_pos': None,
#    'last_hits': 35,
#    'leaver_status': 1,
#    'level': 7,
#    'lh_t': None,
#    'life_state': None,
#    'max_hero_hit': None,
#    'multi_kills': None,
#    'net_worth': 1865,
#    'obs': None,
#    'obs_left_log': None,
#    'obs_log': None,
#    'obs_placed': None,
#    'party_id': 3,
#    'party_size': 1,
#    'performance_others': None,
#    'permanent_buffs': [],
#    'pings': None,
#    'pred_vict': None,
#    'purchase': None,
#    'purchase_log': None,
#    'randomed': None,
#    'repicked': None,
#    'roshans_killed': None,
#    'rune_pickups': None,
#    'runes': None,
#    'runes_log': None,
#    'sen': None,
#    'sen_left_log': None,
#    'sen_log': None,
#    'sen_placed': None,
#    'stuns': None,
#    'teamfight_participation': None,
#    'times': None,
#    'tower_damage': 0,
#    'towers_killed': None,
#    'xp_per_min': 392,
#    'xp_reasons': None,
#    'xp_t': None,
#    'personaname': 'Gigantic Lips',
#    'name': None,
#    'last_login': None,
#    'radiant_win': False,
#    'start_time': 1687725487,
#    'duration': 582,
#    'cluster': 122,
#    'lobby_type': 0,
#    'game_mode': 22,
#    'is_contributor': False,
#    'patch': 52,
#    'region': 2,
#    'isRadiant': True,
#    'win': 0,
#    'lose': 1,
#    'total_gold': 2822,
#    'total_xp': 3802,
#    'kda': 0,
#    'abandons': 0,
#    'rank_tier': 51,
#    'is_subscriber': False,
#    'cosmetics': [],
#    'benchmarks': {'gold_per_min': {'raw': 291, 'pct': 0.04054054054054054},
#     'xp_per_min': {'raw': 392, 'pct': 0.05405405405405406},
#     'kills_per_min': {'raw': 0, 'pct': 0.013513513513513514},
#     'last_hits_per_min': {'raw': 3.6082474226804124,
#      'pct': 0.14864864864864866},
#     'hero_damage_per_min': {'raw': 236.49484536082474,
#      'pct': 0.013513513513513514},
#     'hero_healing_per_min': {'raw': 0, 'pct': 0.9324324324324325},
#     'tower_damage': {'raw': 0, 'pct': 0.02702702702702703},
#     'stuns_per_min': {'raw': 0, 'pct': 0},
#     'lhten': {}}},
#   {'match_id': 7215991100,
#    'player_slot': 4,
#    'ability_targets': None,
#    'ability_upgrades_arr': [5339, 5340, 5339, 5340],
#    'ability_uses': None,
#    'account_id': None,
#    'actions': None,
#    'additional_units': None,
#    'assists': 0,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'backpack_3': None,
#    'buyback_log': None,
#    'camps_stacked': None,
#    'connection_log': None,
#    'creeps_stacked': None,
#    'damage': None,
#    'damage_inflictor': None,
#    'damage_inflictor_received': None,
#    'damage_taken': None,
#    'damage_targets': None,
#    'deaths': 6,
#    'denies': 2,
#    'dn_t': None,
#    'firstblood_claimed': None,
#    'gold': 0,
#    'gold_per_min': 158,
#    'gold_reasons': None,
#    'gold_spent': 1745,
#    'gold_t': None,
#    'hero_damage': 632,
#    'hero_healing': 0,
#    'hero_hits': None,
#    'hero_id': 69,
#    'item_0': 0,
#    'item_1': 0,
#    'item_2': 0,
#    'item_3': 0,
#    'item_4': 0,
#    'item_5': 0,
#    'item_neutral': 0,
#    'item_uses': None,
#    'kill_streaks': None,
#    'killed': None,
#    'killed_by': None,
#    'kills': 0,
#    'kills_log': None,
#    'lane_pos': None,
#    'last_hits': 6,
#    'leaver_status': 3,
#    'level': 4,
#    'lh_t': None,
#    'life_state': None,
#    'max_hero_hit': None,
#    'multi_kills': None,
#    'net_worth': 600,
#    'obs': None,
#    'obs_left_log': None,
#    'obs_log': None,
#    'obs_placed': None,
#    'party_id': 4,
#    'party_size': 1,
#    'performance_others': None,
#    'permanent_buffs': [],
#    'pings': None,
#    'pred_vict': None,
#    'purchase': None,
#    'purchase_log': None,
#    'randomed': None,
#    'repicked': None,
#    'roshans_killed': None,
#    'rune_pickups': None,
#    'runes': None,
#    'runes_log': None,
#    'sen': None,
#    'sen_left_log': None,
#    'sen_log': None,
#    'sen_placed': None,
#    'stuns': None,
#    'teamfight_participation': None,
#    'times': None,
#    'tower_damage': 0,
#    'towers_killed': None,
#    'xp_per_min': 128,
#    'xp_reasons': None,
#    'xp_t': None,
#    'radiant_win': False,
#    'start_time': 1687725487,
#    'duration': 582,
#    'cluster': 122,
#    'lobby_type': 0,
#    'game_mode': 22,
#    'is_contributor': False,
#    'patch': 52,
#    'region': 2,
#    'isRadiant': True,
#    'win': 0,
#    'lose': 1,
#    'total_gold': 1532,
#    'total_xp': 1241,
#    'kda': 0,
#    'abandons': 1,
#    'rank_tier': None,
#    'is_subscriber': False,
#    'cosmetics': [],
#    'benchmarks': {'gold_per_min': {'raw': 158, 'pct': 0},
#     'xp_per_min': {'raw': 128, 'pct': 0},
#     'kills_per_min': {'raw': 0, 'pct': 0.1},
#     'last_hits_per_min': {'raw': 0.6185567010309279, 'pct': 0},
#     'hero_damage_per_min': {'raw': 65.15463917525773, 'pct': 0},
#     'hero_healing_per_min': {'raw': 0, 'pct': 0.85},
#     'tower_damage': {'raw': 0, 'pct': 0.2},
#     'stuns_per_min': {'raw': 0, 'pct': 0},
#     'lhten': {}}},
#   {'match_id': 7215991100,
#    'player_slot': 128,
#    'ability_targets': None,
#    'ability_upgrades_arr': [5116, 5115, 5116, 5115, 5114, 5117],
#    'ability_uses': None,
#    'account_id': None,
#    'actions': None,
#    'additional_units': None,
#    'assists': 2,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'backpack_3': None,
#    'buyback_log': None,
#    'camps_stacked': None,
#    'connection_log': None,
#    'creeps_stacked': None,
#    'damage': None,
#    'damage_inflictor': None,
#    'damage_inflictor_received': None,
#    'damage_taken': None,
#    'damage_targets': None,
#    'deaths': 0,
#    'denies': 10,
#    'dn_t': None,
#    'firstblood_claimed': None,
#    'gold': 571,
#    'gold_per_min': 432,
#    'gold_reasons': None,
#    'gold_spent': 4230,
#    'gold_t': None,
#    'hero_damage': 1415,
#    'hero_healing': 0,
#    'hero_hits': None,
#    'hero_id': 28,
#    'item_0': 44,
#    'item_1': 252,
#    'item_2': 63,
#    'item_3': 0,
#    'item_4': 38,
#    'item_5': 0,
#    'item_neutral': 1124,
#    'item_uses': None,
#    'kill_streaks': None,
#    'killed': None,
#    'killed_by': None,
#    'kills': 1,
#    'kills_log': None,
#    'lane_pos': None,
#    'last_hits': 42,
#    'leaver_status': 0,
#    'level': 6,
#    'lh_t': None,
#    'life_state': None,
#    'max_hero_hit': None,
#    'multi_kills': None,
#    'net_worth': 4711,
#    'obs': None,
#    'obs_left_log': None,
#    'obs_log': None,
#    'obs_placed': None,
#    'party_id': 5,
#    'party_size': 1,
#    'performance_others': None,
#    'permanent_buffs': [],
#    'pings': None,
#    'pred_vict': None,
#    'purchase': None,
#    'purchase_log': None,
#    'randomed': None,
#    'repicked': None,
#    'roshans_killed': None,
#    'rune_pickups': None,
#    'runes': None,
#    'runes_log': None,
#    'sen': None,
#    'sen_left_log': None,
#    'sen_log': None,
#    'sen_placed': None,
#    'stuns': None,
#    'teamfight_participation': None,
#    'times': None,
#    'tower_damage': 591,
#    'towers_killed': None,
#    'xp_per_min': 297,
#    'xp_reasons': None,
#    'xp_t': None,
#    'radiant_win': False,
#    'start_time': 1687725487,
#    'duration': 582,
#    'cluster': 122,
#    'lobby_type': 0,
#    'game_mode': 22,
#    'is_contributor': False,
#    'patch': 52,
#    'region': 2,
#    'isRadiant': False,
#    'win': 1,
#    'lose': 0,
#    'total_gold': 4190,
#    'total_xp': 2880,
#    'kills_per_min': 0.10309278350515465,
#    'kda': 3,
#    'abandons': 0,
#    'rank_tier': None,
#    'is_subscriber': False,
#    'cosmetics': [],
#    'benchmarks': {'gold_per_min': {'raw': 432, 'pct': 0.42857142857142855},
#     'xp_per_min': {'raw': 297, 'pct': 0},
#     'kills_per_min': {'raw': 0.10309278350515463, 'pct': 0.2857142857142857},
#     'last_hits_per_min': {'raw': 4.329896907216495,
#      'pct': 0.42857142857142855},
#     'hero_damage_per_min': {'raw': 145.8762886597938,
#      'pct': 0.14285714285714285},
#     'hero_healing_per_min': {'raw': 0, 'pct': 0.8571428571428571},
#     'tower_damage': {'raw': 591, 'pct': 0.5714285714285714},
#     'stuns_per_min': {'raw': 0, 'pct': 0},
#     'lhten': {}}},
#   {'match_id': 7215991100,
#    'player_slot': 129,
#    'ability_targets': None,
#    'ability_upgrades_arr': [5090, 5685, 5090, 5091, 5090],
#    'ability_uses': None,
#    'account_id': None,
#    'actions': None,
#    'additional_units': None,
#    'assists': 1,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'backpack_3': None,
#    'buyback_log': None,
#    'camps_stacked': None,
#    'connection_log': None,
#    'creeps_stacked': None,
#    'damage': None,
#    'damage_inflictor': None,
#    'damage_inflictor_received': None,
#    'damage_taken': None,
#    'damage_targets': None,
#    'deaths': 0,
#    'denies': 0,
#    'dn_t': None,
#    'firstblood_claimed': None,
#    'gold': 0,
#    'gold_per_min': 208,
#    'gold_reasons': None,
#    'gold_spent': 1295,
#    'gold_t': None,
#    'hero_damage': 2999,
#    'hero_healing': 0,
#    'hero_hits': None,
#    'hero_id': 43,
#    'item_0': 77,
#    'item_1': 44,
#    'item_2': 38,
#    'item_3': 0,
#    'item_4': 4204,
#    'item_5': 29,
#    'item_neutral': 0,
#    'item_uses': None,
#    'kill_streaks': None,
#    'killed': None,
#    'killed_by': None,
#    'kills': 1,
#    'kills_log': None,
#    'lane_pos': None,
#    'last_hits': 8,
#    'leaver_status': 1,
#    'level': 5,
#    'lh_t': None,
#    'life_state': None,
#    'max_hero_hit': None,
#    'multi_kills': None,
#    'net_worth': 1245,
#    'obs': None,
#    'obs_left_log': None,
#    'obs_log': None,
#    'obs_placed': None,
#    'party_id': 6,
#    'party_size': 1,
#    'performance_others': None,
#    'permanent_buffs': [],
#    'pings': None,
#    'pred_vict': None,
#    'purchase': None,
#    'purchase_log': None,
#    'randomed': None,
#    'repicked': None,
#    'roshans_killed': None,
#    'rune_pickups': None,
#    'runes': None,
#    'runes_log': None,
#    'sen': None,
#    'sen_left_log': None,
#    'sen_log': None,
#    'sen_placed': None,
#    'stuns': None,
#    'teamfight_participation': None,
#    'times': None,
#    'tower_damage': 0,
#    'towers_killed': None,
#    'xp_per_min': 240,
#    'xp_reasons': None,
#    'xp_t': None,
#    'radiant_win': False,
#    'start_time': 1687725487,
#    'duration': 582,
#    'cluster': 122,
#    'lobby_type': 0,
#    'game_mode': 22,
#    'is_contributor': False,
#    'patch': 52,
#    'region': 2,
#    'isRadiant': False,
#    'win': 1,
#    'lose': 0,
#    'total_gold': 2017,
#    'total_xp': 2328,
#    'kills_per_min': 0.10309278350515465,
#    'kda': 2,
#    'abandons': 0,
#    'rank_tier': None,
#    'is_subscriber': False,
#    'cosmetics': [],
#    'benchmarks': {'gold_per_min': {'raw': 208, 'pct': 0},
#     'xp_per_min': {'raw': 240, 'pct': 0.125},
#     'kills_per_min': {'raw': 0.10309278350515463, 'pct': 0.5},
#     'last_hits_per_min': {'raw': 0.8247422680412371, 'pct': 0},
#     'hero_damage_per_min': {'raw': 309.17525773195877, 'pct': 0},
#     'hero_healing_per_min': {'raw': 0, 'pct': 0.625},
#     'tower_damage': {'raw': 0, 'pct': 0},
#     'stuns_per_min': {'raw': 0, 'pct': 0.5},
#     'lhten': {}}},
#   {'match_id': 7215991100,
#    'player_slot': 130,
#    'ability_targets': None,
#    'ability_upgrades_arr': [5273, 7300, 5272, 7300, 5272],
#    'ability_uses': None,
#    'account_id': 403397535,
#    'actions': None,
#    'additional_units': None,
#    'assists': 2,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'backpack_3': None,
#    'buyback_log': None,
#    'camps_stacked': None,
#    'connection_log': None,
#    'creeps_stacked': None,
#    'damage': None,
#    'damage_inflictor': None,
#    'damage_inflictor_received': None,
#    'damage_taken': None,
#    'damage_targets': None,
#    'deaths': 1,
#    'denies': 6,
#    'dn_t': None,
#    'firstblood_claimed': None,
#    'gold': 1,
#    'gold_per_min': 274,
#    'gold_reasons': None,
#    'gold_spent': 2200,
#    'gold_t': None,
#    'hero_damage': 3903,
#    'hero_healing': 0,
#    'hero_hits': None,
#    'hero_id': 59,
#    'item_0': 125,
#    'item_1': 29,
#    'item_2': 0,
#    'item_3': 0,
#    'item_4': 0,
#    'item_5': 0,
#    'item_neutral': 0,
#    'item_uses': None,
#    'kill_streaks': None,
#    'killed': None,
#    'killed_by': None,
#    'kills': 0,
#    'kills_log': None,
#    'lane_pos': None,
#    'last_hits': 20,
#    'leaver_status': 1,
#    'level': 5,
#    'lh_t': None,
#    'life_state': None,
#    'max_hero_hit': None,
#    'multi_kills': None,
#    'net_worth': 2301,
#    'obs': None,
#    'obs_left_log': None,
#    'obs_log': None,
#    'obs_placed': None,
#    'party_id': 7,
#    'party_size': 1,
#    'performance_others': None,
#    'permanent_buffs': [],
#    'pings': None,
#    'pred_vict': None,
#    'purchase': None,
#    'purchase_log': None,
#    'randomed': None,
#    'repicked': None,
#    'roshans_killed': None,
#    'rune_pickups': None,
#    'runes': None,
#    'runes_log': None,
#    'sen': None,
#    'sen_left_log': None,
#    'sen_log': None,
#    'sen_placed': None,
#    'stuns': None,
#    'teamfight_participation': None,
#    'times': None,
#    'tower_damage': 0,
#    'towers_killed': None,
#    'xp_per_min': 213,
#    'xp_reasons': None,
#    'xp_t': None,
#    'personaname': 'ch@ppie',
#    'name': None,
#    'last_login': None,
#    'radiant_win': False,
#    'start_time': 1687725487,
#    'duration': 582,
#    'cluster': 122,
#    'lobby_type': 0,
#    'game_mode': 22,
#    'is_contributor': False,
#    'patch': 52,
#    'region': 2,
#    'isRadiant': False,
#    'win': 1,
#    'lose': 0,
#    'total_gold': 2657,
#    'total_xp': 2066,
#    'kda': 1,
#    'abandons': 0,
#    'rank_tier': 43,
#    'is_subscriber': False,
#    'cosmetics': [],
#    'benchmarks': {'gold_per_min': {'raw': 274, 'pct': 0},
#     'xp_per_min': {'raw': 213, 'pct': 0},
#     'kills_per_min': {'raw': 0, 'pct': 0},
#     'last_hits_per_min': {'raw': 2.061855670103093, 'pct': 0},
#     'hero_damage_per_min': {'raw': 402.37113402061857, 'pct': 0.2},
#     'hero_healing_per_min': {'raw': 0, 'pct': 1},
#     'tower_damage': {'raw': 0, 'pct': 0.2},
#     'stuns_per_min': {'raw': 0, 'pct': 0.6},
#     'lhten': {}}},
#   {'match_id': 7215991100,
#    'player_slot': 131,
#    'ability_targets': None,
#    'ability_upgrades_arr': [5080, 5078, 5078, 5080, 5078, 5081, 5078],
#    'ability_uses': None,
#    'account_id': None,
#    'actions': None,
#    'additional_units': None,
#    'assists': 1,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'backpack_3': None,
#    'buyback_log': None,
#    'camps_stacked': None,
#    'connection_log': None,
#    'creeps_stacked': None,
#    'damage': None,
#    'damage_inflictor': None,
#    'damage_inflictor_received': None,
#    'damage_taken': None,
#    'damage_targets': None,
#    'deaths': 0,
#    'denies': 2,
#    'dn_t': None,
#    'firstblood_claimed': None,
#    'gold': 646,
#    'gold_per_min': 382,
#    'gold_reasons': None,
#    'gold_spent': 3665,
#    'gold_t': None,
#    'hero_damage': 1717,
#    'hero_healing': 0,
#    'hero_hits': None,
#    'hero_id': 27,
#    'item_0': 180,
#    'item_1': 232,
#    'item_2': 4204,
#    'item_3': 0,
#    'item_4': 44,
#    'item_5': 0,
#    'item_neutral': 0,
#    'item_uses': None,
#    'kill_streaks': None,
#    'killed': None,
#    'killed_by': None,
#    'kills': 4,
#    'kills_log': None,
#    'lane_pos': None,
#    'last_hits': 24,
#    'leaver_status': 0,
#    'level': 7,
#    'lh_t': None,
#    'life_state': None,
#    'max_hero_hit': None,
#    'multi_kills': None,
#    'net_worth': 4311,
#    'obs': None,
#    'obs_left_log': None,
#    'obs_log': None,
#    'obs_placed': None,
#    'party_id': 8,
#    'party_size': 1,
#    'performance_others': None,
#    'permanent_buffs': [],
#    'pings': None,
#    'pred_vict': None,
#    'purchase': None,
#    'purchase_log': None,
#    'randomed': None,
#    'repicked': None,
#    'roshans_killed': None,
#    'rune_pickups': None,
#    'runes': None,
#    'runes_log': None,
#    'sen': None,
#    'sen_left_log': None,
#    'sen_log': None,
#    'sen_placed': None,
#    'stuns': None,
#    'teamfight_participation': None,
#    'times': None,
#    'tower_damage': 725,
#    'towers_killed': None,
#    'xp_per_min': 354,
#    'xp_reasons': None,
#    'xp_t': None,
#    'radiant_win': False,
#    'start_time': 1687725487,
#    'duration': 582,
#    'cluster': 122,
#    'lobby_type': 0,
#    'game_mode': 22,
#    'is_contributor': False,
#    'patch': 52,
#    'region': 2,
#    'isRadiant': False,
#    'win': 1,
#    'lose': 0,
#    'total_gold': 3705,
#    'total_xp': 3433,
#    'kills_per_min': 0.4123711340206186,
#    'kda': 5,
#    'abandons': 0,
#    'rank_tier': None,
#    'is_subscriber': False,
#    'cosmetics': [],
#    'benchmarks': {'gold_per_min': {'raw': 382, 'pct': 0.7777777777777778},
#     'xp_per_min': {'raw': 354, 'pct': 0.2777777777777778},
#     'kills_per_min': {'raw': 0.41237113402061853, 'pct': 1},
#     'last_hits_per_min': {'raw': 2.4742268041237114,
#      'pct': 0.6666666666666666},
#     'hero_damage_per_min': {'raw': 177.01030927835052, 'pct': 0},
#     'hero_healing_per_min': {'raw': 0, 'pct': 0.7222222222222222},
#     'tower_damage': {'raw': 725, 'pct': 0.16666666666666666},
#     'stuns_per_min': {'raw': 0, 'pct': 0},
#     'lhten': {}}},
#   {'match_id': 7215991100,
#    'player_slot': 132,
#    'ability_targets': None,
#    'ability_upgrades_arr': [5098,
#     5100,
#     5099,
#     5100,
#     5098,
#     5101,
#     5098,
#     5100,
#     5098],
#    'ability_uses': None,
#    'account_id': 111467869,
#    'actions': None,
#    'additional_units': None,
#    'assists': 0,
#    'backpack_0': 0,
#    'backpack_1': 0,
#    'backpack_2': 0,
#    'backpack_3': None,
#    'buyback_log': None,
#    'camps_stacked': None,
#    'connection_log': None,
#    'creeps_stacked': None,
#    'damage': None,
#    'damage_inflictor': None,
#    'damage_inflictor_received': None,
#    'damage_taken': None,
#    'damage_targets': None,
#    'deaths': 0,
#    'denies': 11,
#    'dn_t': None,
#    'firstblood_claimed': None,
#    'gold': 320,
#    'gold_per_min': 569,
#    'gold_reasons': None,
#    'gold_spent': 5810,
#    'gold_t': None,
#    'hero_damage': 2827,
#    'hero_healing': 0,
#    'hero_hits': None,
#    'hero_id': 17,
#    'item_0': 0,
#    'item_1': 98,
#    'item_2': 36,
#    'item_3': 41,
#    'item_4': 237,
#    'item_5': 77,
#    'item_neutral': 0,
#    'item_uses': None,
#    'kill_streaks': None,
#    'killed': None,
#    'killed_by': None,
#    'kills': 3,
#    'kills_log': None,
#    'lane_pos': None,
#    'last_hits': 61,
#    'leaver_status': 0,
#    'level': 9,
#    'lh_t': None,
#    'life_state': None,
#    'max_hero_hit': None,
#    'multi_kills': None,
#    'net_worth': 6090,
#    'obs': None,
#    'obs_left_log': None,
#    'obs_log': None,
#    'obs_placed': None,
#    'party_id': 9,
#    'party_size': 1,
#    'performance_others': None,
#    'permanent_buffs': [],
#    'pings': None,
#    'pred_vict': None,
#    'purchase': None,
#    'purchase_log': None,
#    'randomed': None,
#    'repicked': None,
#    'roshans_killed': None,
#    'rune_pickups': None,
#    'runes': None,
#    'runes_log': None,
#    'sen': None,
#    'sen_left_log': None,
#    'sen_log': None,
#    'sen_placed': None,
#    'stuns': None,
#    'teamfight_participation': None,
#    'times': None,
#    'tower_damage': 525,
#    'towers_killed': None,
#    'xp_per_min': 588,
#    'xp_reasons': None,
#    'xp_t': None,
#    'personaname': 'whopawho',
#    'name': None,
#    'last_login': None,
#    'radiant_win': False,
#    'start_time': 1687725487,
#    'duration': 582,
#    'cluster': 122,
#    'lobby_type': 0,
#    'game_mode': 22,
#    'is_contributor': False,
#    'patch': 52,
#    'region': 2,
#    'isRadiant': False,
#    'win': 1,
#    'lose': 0,
#    'total_gold': 5519,
#    'total_xp': 5703,
#    'kills_per_min': 0.30927835051546393,
#    'kda': 3,
#    'abandons': 0,
#    'rank_tier': None,
#    'is_subscriber': False,
#    'cosmetics': [],
#    'benchmarks': {'gold_per_min': {'raw': 569, 'pct': 0.43548387096774194},
#     'xp_per_min': {'raw': 588, 'pct': 0.1935483870967742},
#     'kills_per_min': {'raw': 0.30927835051546393, 'pct': 0.5161290322580645},
#     'last_hits_per_min': {'raw': 6.288659793814433, 'pct': 0.3548387096774194},
#     'hero_damage_per_min': {'raw': 291.44329896907215,
#      'pct': 0.03225806451612903},
#     'hero_healing_per_min': {'raw': 0, 'pct': 0.8870967741935484},
#     'tower_damage': {'raw': 525, 'pct': 0.24193548387096775},
#     'stuns_per_min': {'raw': 0, 'pct': 0},
#     'lhten': {}}}],
#  'patch': 52,
#  'region': 2,
#  'replay_url': 'http://replay122.valve.net/570/7215991100_1125375967.dem.bz2'}

# %%
for key in match.keys():
    if str(type(match[key])) != "<class 'int'>":
        print(key,type(match[key]))
# Out:
# chat <class 'NoneType'>
# cosmetics <class 'NoneType'>
# dire_team_id <class 'NoneType'>
# draft_timings <class 'NoneType'>
# objectives <class 'NoneType'>
# picks_bans <class 'list'>
# radiant_gold_adv <class 'NoneType'>
# radiant_team_id <class 'NoneType'>
# radiant_win <class 'bool'>
# radiant_xp_adv <class 'NoneType'>
# skill <class 'NoneType'>
# teamfights <class 'NoneType'>
# version <class 'NoneType'>
# players <class 'list'>
# replay_url <class 'str'>

# %% [markdown]
# --
# match_details table
# From API
# 	(dire_score,radiant_score,first_blood_time,patch,region)
# From code
# 	(num_player_account_ids) (0-10 int, for count of players with account_ids)
# 		Some player account_ids show up as None, might be privacy blocked?
#
# Total scope:
# 	match_details(dire_score,radiant_score,first_blood_time,patch,region,num_player_account_ids)
#
# gather player account IDs. If any single player lacks an ID, then make sure num_player_account_ids reflects that. Matches with num_player_account_ids = 10 have enough data for eventual logistic regression based on permutations of MMR that I can look up. Those without 10 account_ids will have gaps and thus aren't suited
# for this version of logistic_regression. Still handy to have match/player data regardless, could use that for dashboarding
#
# then load match details to postgres and load player_performance in a separate table only for those players with account_ids
#
# --
#
# player_performance table:
# From API:
# 	(match_id,account_id, player_slot, deaths, denies, assists, gold_per_min, gold_spent, damage, damate_taken, hero_damage, hero_healing, hero_id, item_0, item_1, item_2, item_3, item_4, item_5, item_neutral, backpack_0, backpack_1, backpack_2, backpack_3, kill_streaks, kills, level, leaver_status, last_hits, net_worth, multi_kills, roshans_killed, rune_pickups, stuns, tower_damage, towers_killed, xp_per_min, isRadiant, kda, abandons)
#
# Check those for lists. any lists should additionally be ignored. any None becomes 0.
#
# Once all that is done, will additionally take the account_ids and do a nextbatch_accountid.csv situation with the 03getnewplayerdetails script. any new account_ids will get their MMR checked. this won't give MMR at time of match result though, so we can't see MMR over time and that will influence historic results... need to investigate this further.

# %%
# 2023-06-25 starting with just one match from this list.
## Ultimately, there will be loops to accomplish each step.
#target_matches = []
#target_matches.append(public_match_results.iloc[0]['match_id']) # just grab the first match for now
#match_details = pd.DataFrame()

# the following code doesn't work. The length of Match dicts are inconsistent.
# will need to evaluate these inconsistencies deeper and then return here.
#for i,target_match in enumerate(target_matches):
#    # target matches are numpy.int64 by default
#    api_string = "https://api.opendota.com/api/matches/"+str(target_match)
#    response = requests.get(api_string)
##    if response.status_code == 200:
#        if i == 0:
#            match_details = pd.DataFrame.from_dict(response.json(), orient='columns') # arrays not of same length
#        else:
#            pass # to be replaced later with Concatenate
#    else:
#        print("Response status code: ", response.status_code)
#        break

# %%
#response.json()
#response.json()['players'][0]
#response2.json()['players'][0]['account_id']
#need player details as well for MMR etc.
#response3 = requests.get("https://api.opendota.com/api/players/416336446")
#response3.json()
# There's the MMR and also the Rank Tier above. 
# #Will take some work to get 100 matches, then 100 match results,
# then 10 players per match result to get all MMRs and rank tiers.
# for spacing out API calls
#print('test')
#time.sleep(2)
#print('test2')
